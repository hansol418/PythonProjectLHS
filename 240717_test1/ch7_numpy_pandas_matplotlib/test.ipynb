# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.random.rand(3)
print(type(data))
print(data)
# Out:
# <class 'numpy.ndarray'>
# [0.07718098 0.94644618 0.41436961]

# %%
seri = pd.Series(data)
print(type(seri))
print(seri)
# Out:
# <class 'pandas.core.series.Series'>
# 0    0.077181
# 1    0.946446
# 2    0.414370
# dtype: float64

# %%
seri.plot()
# Out:
# <Axes: >
